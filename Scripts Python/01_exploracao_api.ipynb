# %%
import requests

url = "https://dadosabertos.camara.leg.br/api/v2/deputados"
response = requests.get(url)

# %%
response.json()
# Out:
# {'dados': [{'id': 204379,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#    'nome': 'Acácio Favacho',
#    'siglaPartido': 'MDB',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#    'siglaUf': 'AP',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204379.jpg',
#    'email': 'dep.acaciofavacho@camara.leg.br'},
#   {'id': 220714,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220714',
#    'nome': 'Adail Filho',
#    'siglaPartido': 'MDB',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#    'siglaUf': 'AM',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/220714.jpg',
#    'email': 'dep.adailfilho@camara.leg.br'},
#   {'id': 221328,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/221328',
#    'nome': 'Adilson Barroso',
#    'siglaPartido': 'PL',
# ...

# %%
len(response.json()['dados'])
# Out:
# 512

# %%
response.json().keys()
# Out:
# dict_keys(['dados', 'links'])

# %%
response.json()['links']
# Out:
# [{'rel': 'self',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados?pagina=1&itens=1000'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados?pagina=1&itens=1000'}]

# %%
url_proposicoes = "https://dadosabertos.camara.leg.br/api/v2/proposicoes"
response_prop = requests.get(url_proposicoes)

# %%
response_prop.status_code
# Out:
# 200

# %%
len(response_prop.json()['dados'])
# Out:
# 15

# %%
response_prop.json()
# Out:
# {'dados': [{'id': 14666,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/14666',
#    'siglaTipo': 'PEC',
#    'codTipo': 136,
#    'numero': 290,
#    'ano': 2000,
#    'ementa': 'Dá nova redação aos art. 49, 50 e 58 da Constituição Federal, regulando a convocação de Ministros de Estado, titular de órgão vinculado à Presidência da República, dirigentes da administração direta, indireta, de entidade reguladora ou de serviço público pelo Congresso Nacional.',
#    'dataApresentacao': '2000-10-03T00:00'},
#   {'id': 104333,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/104333',
#    'siglaTipo': 'PL',
#    'codTipo': 139,
#    'numero': 11,
#    'ano': 2003,
#    'ementa': 'Proíbe a veiculação de peças publicitárias, em qualquer meio de comunicação, que utilizem imagens sexuais como atrativo.',
#    'dataApresentacao': '2003-02-18T14:35'},
#   {'id': 104417,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/104417',
# ...

# %%
response_prop.json()['links']
# Out:
# [{'rel': 'self',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes'},
#  {'rel': 'next',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?pagina=2&itens=15'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?pagina=1&itens=15'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?pagina=2552&itens=15'}]

# %%
params = {
    'dataInicio': '2024-05-01',
    'dataFim': '2024-05-31',
    'itens': 100
}

response_prop_filtrado = requests.get(url_proposicoes, params=params)
response_prop_filtrado.json()['links']
# Out:
# [{'rel': 'self',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?dataInicio=2024-05-01&dataFim=2024-05-31&itens=100'},
#  {'rel': 'next',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?dataInicio=2024-05-01&dataFim=2024-05-31&pagina=2&itens=100'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?dataInicio=2024-05-01&dataFim=2024-05-31&pagina=1&itens=100'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?dataInicio=2024-05-01&dataFim=2024-05-31&pagina=126&itens=100'}]

# %%
response_votacoes = requests.get("https://dadosabertos.camara.leg.br/api/v2/votacoes")
print(len(response_votacoes.json()['dados']))
response_votacoes.json()['links']
# Out:
# 100
# [{'rel': 'self', 'href': 'https://dadosabertos.camara.leg.br/api/v2/votacoes'},
#  {'rel': 'next',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/votacoes?pagina=2&itens=100'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/votacoes?pagina=1&itens=100'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/votacoes?pagina=46&itens=100'}]

# %%
response_despesas = requests.get("https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas")
response_despesas.json()['links']
# Out:
# [{'rel': 'self',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas'},
#  {'rel': 'next',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas?pagina=2&itens=15'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas?pagina=1&itens=15'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas?pagina=8&itens=15'}]

# %%
response_partidos = requests.get("https://dadosabertos.camara.leg.br/api/v2/partidos")
response_partidos.json()['links']
# Out:
# [{'rel': 'self', 'href': 'https://dadosabertos.camara.leg.br/api/v2/partidos'},
#  {'rel': 'next',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/partidos?pagina=2&itens=15'},
#  {'rel': 'first',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/partidos?pagina=1&itens=15'},
#  {'rel': 'last',
#   'href': 'https://dadosabertos.camara.leg.br/api/v2/partidos?pagina=2&itens=15'}]
